# %% [markdown]
# <a href="https://colab.research.google.com/github/vilsonrodrigues/DigitalImageProcessing/blob/main/DCA0445/lesson2-trocaregioes/pdi_lesson2_trocaregioes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lesson 2: Switch regions

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Read image as gray

# %%
img = cv2.imread("biel.png", cv2.COLOR_RGB2GRAY)

# %% [markdown]
# Dimensions

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
plt.imshow(img)

# %%
axisX, axisY, _ = img.shape

# %%
centerPointX = int(axisX /2)
centerPointY = int(axisY /2)

# %% [markdown]
# Plot slices

# %%
plt.imshow(img[0:centerPointX,0:centerPointY])

# %%
plt.imshow(img[centerPointX:axisX,0:centerPointY])

# %%
plt.imshow(img[0:centerPointX,centerPointY:axisY])

# %%
plt.imshow(img[centerPointX:axisX,centerPointY:axisY])

# %%
img_switch = img.copy()

# %% [markdown]
# Switch regions

# %%
img_switch[0:centerPointX,0:centerPointY] = img[centerPointX:axisX,centerPointY:axisY]
img_switch[0:centerPointX,centerPointY:axisY] = img[centerPointX:axisX,0:centerPointY]
img_switch[centerPointX:axisX,0:centerPointY] = img[0:centerPointX,centerPointY:axisY]
img_switch[centerPointX:axisX,centerPointY:axisY] = img[0:centerPointX,0:centerPointY]

# %%
plt.imshow(img_switch)
